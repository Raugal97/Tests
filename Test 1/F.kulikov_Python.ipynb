# %% [markdown]
# # Напишите код на языке Питоне, который решает все 5 заданий. Перед каждым новым блоком оставьте внутри кода комментарий, к какому заданию он относится. Ответ передайте в любом удобном для вас виде (кроме скриншота).
#
# -------------------------------------------------------------------------------------------------------------
#
# У вас есть список мужчин с именами и фамилиями:
# Eddard Stark
# Robb Stark
# Jaime Lannister
# Tyrion Lannister
# Joffrey Baratheon
# Robert Baratheon
# Viserys Targaryen
# Jon Snow
#
# И аналогичный список женщин:
# Catelyn Stark
# Sansa Stark
# Cersei Lannister
# Daenerys Targaryen

# %% [markdown]
# # Задание 1
# Создайте отдельный список с мужчинами и отдельный список с женщинами.

# %%
M_list = ['Eddard Stark',
'Robb Stark',
'Jaime Lannister',
'Tyrion Lannister',
'Joffrey Baratheon',
'Robert Baratheon',
'Viserys Targaryen',
'Jon Snow']

F_list = ['Catelyn Stark',
'Sansa Stark',
'Cersei Lannister',
'Daenerys Targaryen']

# %% [markdown]
# # Задание 2
# Допустим, что все мужчины и женщины выстроились в линию в алфавитном порядке и рассчитались на первый-второй. Нужно получить список людей, которые оказались вторыми.
#
# Для этого напишите функцию, которая принимает в качестве аргументов два списка с мужчинами и женщинами и возвращает список людей, оказавшихся вторыми.
#
# Примечание: для нахождения алфавитного порядка НЕ нужно менять местами имя и фамилию.

# %%
def lets_sort(x, y):
    combined_list = x + y
    return(sorted(combined_list)[1::2])

# %%
lets_sort(M_list, F_list)
# Out:
# ['Cersei Lannister',
#  'Eddard Stark',
#  'Joffrey Baratheon',
#  'Robb Stark',
#  'Sansa Stark',
#  'Viserys Targaryen']

# %% [markdown]
# # Задание 3
# Для каждой пары людей узнайте, являются ли они однофамильцами. Для этого создайте словарь, где ключом является пара людей. Значением словаря будет 1, если пара является однофамильцами, и 0, если их фамилии отличаются.
#
# Примечание 1: в паре могут быть люди любого пола.
# Примечание 2: порядок людей в паре значения не имеет.
# Примечание 3: тип данных и значение ключа может быть любым, с которым вам удобно работать. Главное, чтобы по ключу было понятно, кто именно входит в пару.

# %%
import itertools

combined_list = M_list + F_list

pairs_dict = {}


pairs_list = [(x,y) for x,y in itertools.combinations(combined_list,2)]

for item in pairs_list:
    if item[0].split()[1] == item[1].split()[1]:
        pairs_dict[item] = 1
    else:
        pairs_dict[item] = 0

        
pairs_dict
# Out:
# {('Eddard Stark', 'Robb Stark'): 1,
#  ('Eddard Stark', 'Jaime Lannister'): 0,
#  ('Eddard Stark', 'Tyrion Lannister'): 0,
#  ('Eddard Stark', 'Joffrey Baratheon'): 0,
#  ('Eddard Stark', 'Robert Baratheon'): 0,
#  ('Eddard Stark', 'Viserys Targaryen'): 0,
#  ('Eddard Stark', 'Jon Snow'): 0,
#  ('Eddard Stark', 'Catelyn Stark'): 1,
#  ('Eddard Stark', 'Sansa Stark'): 1,
#  ('Eddard Stark', 'Cersei Lannister'): 0,
#  ('Eddard Stark', 'Daenerys Targaryen'): 0,
#  ('Robb Stark', 'Jaime Lannister'): 0,
#  ('Robb Stark', 'Tyrion Lannister'): 0,
#  ('Robb Stark', 'Joffrey Baratheon'): 0,
#  ('Robb Stark', 'Robert Baratheon'): 0,
#  ('Robb Stark', 'Viserys Targaryen'): 0,
#  ('Robb Stark', 'Jon Snow'): 0,
#  ('Robb Stark', 'Catelyn Stark'): 1,
#  ('Robb Stark', 'Sansa Stark'): 1,
#  ('Robb Stark', 'Cersei Lannister'): 0,
#  ('Robb Stark', 'Daenerys Targaryen'): 0,
#  ('Jaime Lannister', 'Tyrion Lannister'): 1,
#  ('Jaime Lannister', 'Joffrey Baratheon'): 0,
# ...

# %% [markdown]
# # Задание 4
# Узнайте состав каждой семьи, которая встречается в предоставленных списках. Для этого создайте словарь, где ключом является фамилия. Значением словаря будет список всех однофамильцев (и мужчин, и женщин).

# %%
family_dict = {}

for person in combined_list:
    surname = person.split()[1]
    family_dict[surname] = family_dict.get(surname, [])
    family_dict[surname].append(person)
family_dict
# Out:
# {'Stark': ['Eddard Stark', 'Robb Stark', 'Catelyn Stark', 'Sansa Stark'],
#  'Lannister': ['Jaime Lannister', 'Tyrion Lannister', 'Cersei Lannister'],
#  'Baratheon': ['Joffrey Baratheon', 'Robert Baratheon'],
#  'Targaryen': ['Viserys Targaryen', 'Daenerys Targaryen'],
#  'Snow': ['Jon Snow']}

# %% [markdown]
# # Задание 5
# Узнайте размер каждой семьи, используя словарь из задания 4. В качестве ответа выведите на экран несколько строчек: в каждой строчке должна быть указана семья и ее размер. Для вывода на экран используйте команду print().
#
# Пример оформления:
# Snow: 1

# %%
for key, value in family_dict.items():
    print(f'{key}:{len(value)}')
# Out:
# Stark:4
# Lannister:3
# Baratheon:2
# Targaryen:2
# Snow:1
